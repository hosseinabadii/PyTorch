# %% [markdown]
# # Building a binary-class PyTorch model

# %% [markdown]
# ## 1. Import libraries

# %%
import torch
import torch.nn as nn

import pandas as pd
import matplotlib.pyplot as plt

from torchinfo import summary
from torcheval.metrics.functional import binary_accuracy, binary_confusion_matrix

from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix

from helper_functions import plot_decision_boundary, plot_loss_curves
from tqdm.auto import tqdm

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 2. Create data

# %% [markdown]
# ### 2.1 Creating dataset of circles

# %%
NUM_SAMPLES = 1000
RANDOM_SEED = 101

X_array, y_array = make_circles(
    n_samples=NUM_SAMPLES,
    noise=0.03,
    random_state=RANDOM_SEED,
)

print(f"X shape: {X_array.shape}")
print(f"y shape: {y_array.shape}")
print(f"\nFirst 5 samples od X:\n {X_array[:5]}")
print(f"\nFirst 5 samples od y:\n {y_array[:5]}")
# Out:
# X shape: (1000, 2)
# y shape: (1000,)
#
# First 5 samples od X:
#  [[ 0.67621763  0.49758361]
#  [-0.81272345 -0.54300962]
#  [ 0.19260493  1.0200862 ]
#  [-0.3206205  -0.69172039]
#  [-0.77961897  0.64546739]]
#
# First 5 samples od y:
#  [1 0 0 1 0]

# %% [markdown]
# ### 2.2 Plot the dataset

# %%
circles = pd.DataFrame({"X1": X_array[:, 0], "X2": X_array[:, 1], "label": y_array})
plt.scatter(x=X_array[:, 0], y=X_array[:, 1], c=y_array, cmap=plt.cm.RdYlBu);

# %% [markdown]
# ### 2.3 Convert numpy array to torch tensor

# %%
X = torch.from_numpy(X_array).type(torch.float)
y = torch.from_numpy(y_array).type(torch.float) # must be float, not integer

print(f"X dtype: {X.dtype}, X shape: {X.shape}")
print(f"y dtype: {y.dtype}, X shape: {y.shape}")
# Out:
# X dtype: torch.float32, X shape: torch.Size([1000, 2])
# y dtype: torch.float32, X shape: torch.Size([1000])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_SEED
)

print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"X_test : {y_test.shape}")
# Out:
# X_train: torch.Size([800, 2])
# y_train: torch.Size([800])
# X_test : torch.Size([200, 2])
# X_test : torch.Size([200])

# %% [markdown]
# ## 3. Building a binary-class classification model in PyTorch

# %% [markdown]
# ### 3.1 Creating the model

# %%
class CircleModel(nn.Module):
    def __init__(self, input_features, output_features, hidden_units):
        super().__init__()
        self.linear_layer_stack = nn.Sequential(
            nn.Linear(in_features=input_features, out_features=hidden_units),
            nn.ReLU(),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.ReLU(),
            nn.Linear(in_features=hidden_units, out_features=output_features),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.linear_layer_stack(x)

# %%
torch.manual_seed(RANDOM_SEED)

model = CircleModel(input_features=2, output_features=1, hidden_units=10)
summary(
    model,
    input_size=(2,),
    col_names=["input_size", "output_size", "num_params", "trainable"],
)
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# CircleModel                              [2]                       [1]                       --                        True
# ├─Sequential: 1-1                        [2]                       [1]                       --                        True
# │    └─Linear: 2-1                       [2]                       [10]                      30                        True
# │    └─ReLU: 2-2                         [10]                      [10]                      --                        --
# │    └─Linear: 2-3                       [10]                      [10]                      110                       True
# │    └─ReLU: 2-4                         [10]                      [10]                      --                        --
# │    └─Linear: 2-5                       [10]                      [1]                       11                        True
# ============================================================================================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ============================================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ============================================================================================================================================

# %% [markdown]
# ### 3.2. Creating a loss function and optimizer

# %%
# Create a loss function
# loss_fn = nn.BCELoss()          # BCELoss = no sigmoid built-in
loss_fn = nn.BCEWithLogitsLoss()  # BCEWithLogitsLoss = sigmoid built-in
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# %% [markdown]
# ### 3.3 Getting prediction probabilities for a multi-class PyTorch model

# %%
model.eval()
with torch.inference_mode():
    untrained_logits = model(X_test)

print(f"untrained logits shape: {untrained_logits.shape}")
print(f"first 5 untrained logits:\n{untrained_logits[:5]}")

untrained_preds = torch.sigmoid(untrained_logits)
print(f"\nuntrained preds shape: {untrained_preds.shape}")
print(f"first 5 untrained preds:\n{untrained_preds[:5]}")

untrained_classes = torch.round(untrained_preds)
print(f"\nfirst 5 untrained_classes:\n{untrained_classes.squeeze()[:5]}")
print(f"\nfirst 5 labels:\n{y_test[:5]}")
# Out:
# untrained logits shape: torch.Size([200, 1])
# first 5 untrained logits:
# tensor([[ 0.0058],
#         [-0.0111],
#         [-0.0420],
#         [-0.0372],
#         [-0.0220]])
#
# untrained preds shape: torch.Size([200, 1])
# first 5 untrained preds:
# tensor([[0.5015],
#         [0.4972],
#         [0.4895],
#         [0.4907],
#         [0.4945]])
#
# first 5 untrained_classes:
# tensor([1., 0., 0., 0., 0.])
#
# first 5 labels:
# tensor([0., 0., 1., 1., 0.])

# %% [markdown]
# ## 4. Train and test the model

# %% [markdown]
# ### 4.1 training loop

# %%
def train(
    epochs: int,
    model: torch.nn.Module,
    X_train: torch.Tensor,
    X_test: torch.Tensor,
    y_train: torch.Tensor,
    y_test: torch.Tensor,
    optimizer: torch.optim.Optimizer,
    loss_fn: torch.nn.Module,
    print_step: int = 10,
) -> dict[str, list]:

    results = {"train_loss": [], "train_acc": [], "test_loss": [], "test_acc": []}

    for epoch in tqdm(range(1, epochs + 1)):

        model.train()

        y_logits = model(X_train).squeeze() # must be squeezed

        loss = loss_fn(y_logits, y_train)
        train_loss = loss.item()
        ## Using nn.BCELoss you need torch.sigmoid()
        # loss = loss_fn(torch.sigmoid(y_logits), y_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        y_pred = torch.round(torch.sigmoid(y_logits))
        train_acc = binary_accuracy(y_pred, y_train)

        model.eval()
        with torch.inference_mode():
            test_logits = model(X_test).squeeze()
            test_loss = loss_fn(test_logits, y_test)

            test_pred = torch.round(torch.sigmoid(test_logits))
            test_acc = binary_accuracy(test_pred, y_test)

        if (epoch % print_step == 0) or (epoch == epochs):
            tqdm.write(
                f"Epoch: {epoch:3} | "
                f"train_loss: {train_loss:.4f} | "
                f"train_acc: {train_acc:.4f} | "
                f"test_loss: {test_loss:.4f} | "
                f"test_acc: {test_acc:.4f}"
            )

        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    return results

# %%
results = train(
    epochs=3000,
    model=model,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    optimizer=optimizer,
    loss_fn=loss_fn,
    print_step=100,
)
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Epoch: 100 | train_loss: 0.6930 | train_acc: 0.5512 | test_loss: 0.6955 | test_acc: 0.4750
# Epoch: 200 | train_loss: 0.6909 | train_acc: 0.5400 | test_loss: 0.6940 | test_acc: 0.4750
# Epoch: 300 | train_loss: 0.6892 | train_acc: 0.5825 | test_loss: 0.6924 | test_acc: 0.5450
# Epoch: 400 | train_loss: 0.6871 | train_acc: 0.6162 | test_loss: 0.6901 | test_acc: 0.5750
# Epoch: 500 | train_loss: 0.6841 | train_acc: 0.7225 | test_loss: 0.6869 | test_acc: 0.7100
# Epoch: 600 | train_loss: 0.6796 | train_acc: 0.7312 | test_loss: 0.6825 | test_acc: 0.7200
# Epoch: 700 | train_loss: 0.6729 | train_acc: 0.6687 | test_loss: 0.6762 | test_acc: 0.6700
# Epoch: 800 | train_loss: 0.6624 | train_acc: 0.6837 | test_loss: 0.6668 | test_acc: 0.6650
# Epoch: 900 | train_loss: 0.6452 | train_acc: 0.7188 | test_loss: 0.6505 | test_acc: 0.6800
# Epoch: 1000 | train_loss: 0.6156 | train_acc: 0.8012 | test_loss: 0.6197 | test_acc: 0.7600
# Epoch: 1100 | train_loss: 0.5645 | train_acc: 0.8525 | test_loss: 0.5650 | test_acc: 0.8350
# Epoch: 1200 | train_loss: 0.4881 | train_acc: 0.9287 | test_loss: 0.4841 | test_acc: 0.9150
# Epoch: 1300 | train_loss: 0.3865 | train_acc: 0.9837 | test_loss: 0.3786 | test_acc: 0.9800
# Epoch: 1400 | train_loss: 0.2777 | train_acc: 0.9987 | test_loss: 0.2684 | test_acc: 0.9950
# Epoch: 1500 | train_loss: 0.3348 | train_acc: 0.8425 | test_loss: 0.2970 | test_acc: 0.8300
# Epoch: 1600 | train_loss: 0.3202 | train_acc: 0.8363 | test_loss: 0.2813 | test_acc: 0.8350
# Epoch: 1700 | train_loss: 0.3490 | train_acc: 0.7987 | test_loss: 0.2971 | test_acc: 0.7950
# Epoch: 1800 | train_loss: 0.1009 | train_acc: 0.9962 | test_loss: 0.0975 | test_acc: 0.9950
# Epoch: 1900 | train_loss: 0.0762 | train_acc: 0.9975 | test_loss: 0.0721 | test_acc: 0.9950
# Epoch: 2000 | train_loss: 0.0596 | train_acc: 0.9975 | test_loss: 0.0570 | test_acc: 0.9950
# Epoch: 2100 | train_loss: 0.0485 | train_acc: 0.9975 | test_loss: 0.0466 | test_acc: 0.9950
# Epoch: 2200 | train_loss: 0.0407 | train_acc: 0.9975 | test_loss: 0.0395 | test_acc: 0.9950
# Epoch: 2300 | train_loss: 0.0348 | train_acc: 0.9987 | test_loss: 0.0343 | test_acc: 0.9950
# Epoch: 2400 | train_loss: 0.0302 | train_acc: 0.9987 | test_loss: 0.0305 | test_acc: 0.9950
# Epoch: 2500 | train_loss: 0.0266 | train_acc: 0.9987 | test_loss: 0.0276 | test_acc: 0.9950
# Epoch: 2600 | train_loss: 0.0238 | train_acc: 1.0000 | test_loss: 0.0251 | test_acc: 0.9950
# Epoch: 2700 | train_loss: 0.0215 | train_acc: 1.0000 | test_loss: 0.0231 | test_acc: 0.9950
# Epoch: 2800 | train_loss: 0.0196 | train_acc: 1.0000 | test_loss: 0.0214 | test_acc: 0.9950
# Epoch: 2900 | train_loss: 0.0180 | train_acc: 1.0000 | test_loss: 0.0200 | test_acc: 0.9950
# Epoch: 3000 | train_loss: 0.0167 | train_acc: 1.0000 | test_loss: 0.0188 | test_acc: 0.9950

# %% [markdown]
# ### 4.2 Plot loss and accuracy curves

# %%
plot_loss_curves(results)

# %% [markdown]
# ### 4.3 Plot the bounbaries

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model, X_test, y_test)

# %% [markdown]
# ### 4.4 Making and evaluating predictions

# %%
model.eval()
with torch.inference_mode():
    y_pred_probs_test = model(X_test).squeeze()
    y_pred_test = torch.round(torch.sigmoid(y_pred_probs_test))
    test_loss = loss_fn(y_pred_probs_test, y_test)
    test_acc = binary_accuracy(y_pred_test, y_test)

print(f"First 10 predictions : {y_pred_test[:10]}")
print(f"First 10 labels      : {y_test[:10]}")
print(f"Test accuracy        : {test_acc:.3f}")
# Out:
# First 10 predictions : tensor([0., 0., 1., 1., 0., 1., 0., 0., 0., 0.])
# First 10 labels      : tensor([0., 0., 1., 1., 0., 1., 0., 0., 0., 0.])
# Test accuracy        : 0.995

# %% [markdown]
# ### 4.5 Plot confusion matrix

# %%
cm = binary_confusion_matrix(y_pred_test, y_test.type(torch.int64)) # must be int64, not float
fig, ax = plot_confusion_matrix(cm.numpy(), figsize=(10, 7))
